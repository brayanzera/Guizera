# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming you have a DataFrame df with "topico 1" as columns and "topico 2" as rows
# Replace df with your actual DataFrame

# Sample DataFrame creation
data = {'topico 1': [10, 15, 20], 'topico 2': [5, 8, 12]}
df = pd.read_csv('Leitos_2020.csv')

# Plotting the bar chart
ax = df.plot(kind='bar')
ax.set_ylabel("Values")  # Set y-axis label
ax.set_xlabel("Rows")    # Set x-axis label
plt.title("Bar Chart: topico 1 vs topico 2")  # Set chart title
plt.show()
